# %% [markdown]
# ## What is Index Intersection?
#
# Index intersection provides the ability to execute a performant query that spans multiple indexes in your data store. This means you can write ad-hoc, dynamically generated queries, where you don't need to know the query, fields or ordering of fields in advance.

# %% [markdown]
# ## Your application is in a constant state of evolution
#
# Let’s say we have a hypothetical movie application with documents like:

# %%
import pymongo
# from config import mongo_uri
from pymongoexplain import ExplainableCollection
import pprint

pp = pprint.PrettyPrinter()

doc = {
  "title": "Fight Club",
  "year": 1999,
  "imdb": {
    "rating": 8.9,
    "votes": 1191784,
    "id": 137523
  },
  "cast":[
    "Edward Norton",
    "Brad Pitt"
  ]
}

# connect
conn = pymongo.MongoClient("mongo_uri")
collection = conn['sample_mflix']['movies']

# insert
collection.insert_one(doc)

# %% [markdown]
# ## Initial Product Requirements
#
# Now for the version 1.0 requirements, you need to query on title & year, so you first create a compound index:

# %%
collection.create_index([
    ('title', 1),
    ('year', 1)
], name='title_year', default_language='english')
# Out:
# 'title_year'

# %%
pipeline = [
    {"$match":{"title":"Fight Club", "year":1999} }
]

explain_plan = ExplainableCollection(
    collection, 
    verbosity="executionStats"
).aggregate(pipeline)

pp.pprint(explain_plan['executionStats']['executionStages'])
# Out:
# {'advanced': 4,
#  'alreadyHasObj': 0,
#  'docsExamined': 4,
#  'executionTimeMillisEstimate': 0,
#  'inputStage': {'advanced': 4,
#                 'direction': 'forward',
#                 'dupsDropped': 0,
#                 'dupsTested': 0,
#                 'executionTimeMillisEstimate': 0,
#                 'indexBounds': {'title': ['["Fight Club", "Fight Club"]'],
#                                 'year': ['[1999, 1999]']},
#                 'indexName': 'title_year',
#                 'indexVersion': 2,
#                 'isEOF': 1,
#                 'isMultiKey': False,
#                 'isPartial': False,
#                 'isSparse': False,
#                 'isUnique': False,
#                 'keyPattern': {'title': 1, 'year': 1},
#                 'keysExamined': 4,
#                 'multiKeyPaths': {'title': [], 'year': []},
#                 'nReturned': 4,
#                 'needTime': 0,
#                 'needYield': 0,
#                 'restoreState': 0,
#                 'saveState': 0,
#                 'seeks': 1,
#                 'stage': 'IXSCAN',
#                 'works': 5},
#  'isEOF': 1,
#  'nReturned': 4,
#  'needTime': 0,
#  'needYield': 0,
#  'restoreState': 0,
#  'saveState': 0,
#  'stage': 'FETCH',
#  'works': 5}

# %% [markdown]
# ## Our query evolves
#
# Now our application requirements have evolved and you need to query on cast and imdb. First you create the index, then issue the query:

# %%
collection.create_index([
    ('cast', 1),
    ('imdb.rating', 1)
], name='cast_rating', default_language='english')
# Out:
# 'cast_rating'

# %%
pipeline = [
    {"$match":{"cast":"Edward Norton", "imdb.rating":{ "$gte":9 } } }
]

explain_plan = ExplainableCollection(
    collection, 
    verbosity="executionStats"
).aggregate(pipeline)

pp.pprint(explain_plan['executionStats']['executionStages'])
# Out:
# {'advanced': 0,
#  'alreadyHasObj': 0,
#  'docsExamined': 0,
#  'executionTimeMillisEstimate': 0,
#  'inputStage': {'advanced': 0,
#                 'direction': 'forward',
#                 'dupsDropped': 0,
#                 'dupsTested': 0,
#                 'executionTimeMillisEstimate': 0,
#                 'indexBounds': {'cast': ['["Edward Norton", "Edward Norton"]'],
#                                 'imdb.rating': ['[9, inf.0]']},
#                 'indexName': 'cast_rating',
#                 'indexVersion': 2,
#                 'isEOF': 1,
#                 'isMultiKey': True,
#                 'isPartial': False,
#                 'isSparse': False,
#                 'isUnique': False,
#                 'keyPattern': {'cast': 1, 'imdb.rating': 1},
#                 'keysExamined': 0,
#                 'multiKeyPaths': {'cast': ['cast'], 'imdb.rating': []},
#                 'nReturned': 0,
#                 'needTime': 0,
#                 'needYield': 0,
#                 'restoreState': 0,
#                 'saveState': 0,
#                 'seeks': 1,
#                 'stage': 'IXSCAN',
#                 'works': 1},
#  'isEOF': 1,
#  'nReturned': 0,
#  'needTime': 0,
#  'needYield': 0,
#  'restoreState': 0,
#  'saveState': 0,
#  'stage': 'FETCH',
#  'works': 1}

# %% [markdown]
# ## And our query retracts
#
# Now, our application requires you issue a new query, a subset of the original:

# %%
pipeline = [
    {"$match":{"imdb.rating" : { "$gte":9 } } }
]

explain_plan = ExplainableCollection(
    collection, 
    verbosity="executionStats"
).aggregate(pipeline)

pp.pprint(explain_plan['executionStats']['executionStages'])
# Out:
# {'advanced': 31,
#  'direction': 'forward',
#  'docsExamined': 23535,
#  'executionTimeMillisEstimate': 3,
#  'filter': {'imdb.rating': {'$gte': 9}},
#  'isEOF': 1,
#  'nReturned': 31,
#  'needTime': 23505,
#  'needYield': 0,
#  'restoreState': 23,
#  'saveState': 23,
#  'stage': 'COLLSCAN',
#  'works': 23537}

# %% [markdown]
# The query above results in the dreaded collection scan despite the previous compound index (cast_imdb.rating) comprising the above query’s key.
#
# __Note: Collection scans should be avoided because not only do they instruct the cursor to look at every document in the collection which is slow, but it also forces documents out of memory resulting in increased I/O pressure.__
#
# Now you certainly could create a new index composed of just imdb.rating, which would return an index scan for the above query,  but that’s three different indexes that the query planner would have to navigate in order to select the most performant response.
#
# ## Alternatively: Atlas Search
#
# Because Lucene uses a different index data structure (inverted indexes vs B-tree indexes) it’s purpose-built to handle index intersection well.
#
# If you create a single index that maps all of our 4 fields above (title, year, cast, imdb):

# %%
{
  "mappings": {
    "dynamic": False,
    "fields": {
      "title": {
        "type": "string",
        "dynamic": False
      },
      "year": {
        "type": "number",
        "dynamic": False
      },
      "cast": {
        "type": "string",
        "dynamic": False
      },
      "imdb.rating": {
        "type": "number",
        "dynamic": False
      }                  
    }
  }
}
# Out:
# {'mappings': {'dynamic': False,
#   'fields': {'title': {'type': 'string', 'dynamic': False},
#    'year': {'type': 'number', 'dynamic': False},
#    'cast': {'type': 'string', 'dynamic': False},
#    'imdb.rating': {'type': 'number', 'dynamic': False}}}}

# %% [markdown]
# Then you issue a query that first spans title & year via a must (AND) clause, which is the equivalent of  `db.collection.find({"title":"Fight Club", "year":1999})`:

# %%
pipeline = [{
  "$search": {
    "compound": {
      "must": [{
          "text": {
            "query": "Fight Club",
            "path": "title"
          }
        },
        {
          "range": {
            "path": "year",
            "gte": 1999,
            "lte": 1999
          }
        }
      ]
    }
  }
}]

explain_plan = ExplainableCollection(
    collection, 
    verbosity="allPlansExecution"
).aggregate(pipeline)

pp.pprint(explain_plan)
# Out:
# {'$clusterTime': {'clusterTime': Timestamp(1664299192, 1),
#                   'signature': {'hash': b'\x9d\\\xdb\xaf\xaf\xc0\xba\x97j\xd5cJ'
#                                         b'\x11*\x94\x10\x00\x1c\xf3\xfa',
#                                 'keyId': 7109841346575204358}},
#  'command': {'$db': 'sample_mflix',
#              'aggregate': 'movies',
#              'cursor': {},
#              'pipeline': [{'$search': {'compound': {'must': [{'text': {'path': 'title',
#                                                                        'query': 'Fight '
#                                                                                 'Club'}},
#                                                              {'range': {'gte': 1999,
#                                                                         'lte': 1999,
#                                                                         'path': 'year'}}]}}}]},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'operationTime': Timestamp(1664299192, 1),
#  'serverInfo': {'gitVersion': '32f0f9c88dc44a2c8073a5bd47cf779d4bfdee6b',
#                 'host': 'atlas-mrr4hc-shard-00-01.v7a3k.mongodb.net',
#                 'port': 27017,
#                 'version': '6.0.1'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0},
#  'stages': [{'$_internalSearchMongotRemote': {'explain': {'args': {'filter': [],
#                                                                    'minimumShouldMatch': 0,
#                                                                    'must': [{'args': {'filter': [],
#                                                                                       'minimumShouldMatch': 0,
#                                                                                       'must': [],
#                                                                                       'mustNot': [],
#                                                                                       'should': [{'args': {'gte': 1999.0,
#                                                                                                            'lte': 1999.0,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'double'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 5684},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 1999,
#                                                                                                            'lte': 1999,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'int64'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 3463},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 1999,
#                                                                                                            'lte': 1999,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'int64'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 12210},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 1999.0,
#                                                                                                            'lte': 1999.0,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'double'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 571769},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'invocationCounts': {'score': 4},
#                                                                                                                       'nanosElapsed': 1231}},
#                                                                                                   'type': 'PointRangeQuery'}]},
#                                                                              'path': 'compound.must[1]',
#                                                                              'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                         'createWeight': 1},
#                                                                                                    'nanosElapsed': 693105},
#                                                                                        'match': {'nanosElapsed': 0},
#                                                                                        'score': {'invocationCounts': {'score': 4},
#                                                                                                  'nanosElapsed': 2470}},
#                                                                              'type': 'BooleanQuery'},
#                                                                             {'args': {'filter': [],
#                                                                                       'minimumShouldMatch': 0,
#                                                                                       'must': [],
#                                                                                       'mustNot': [],
#                                                                                       'should': [{'args': {'path': 'title',
#                                                                                                            'value': 'fight'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 241815},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'invocationCounts': {'score': 3},
#                                                                                                                       'nanosElapsed': 3939}},
#                                                                                                   'type': 'TermQuery'},
#                                                                                                  {'args': {'path': 'title',
#                                                                                                            'value': 'club'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 145428},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'invocationCounts': {'score': 4},
#                                                                                                                       'nanosElapsed': 1198}},
#                                                                                                   'type': 'TermQuery'}]},
#                                                                              'path': 'compound.must[0]',
#                                                                              'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                         'createWeight': 1},
#                                                                                                    'nanosElapsed': 1252906},
#                                                                                        'match': {'invocationCounts': {'refineRoughMatch': 4},
#                                                                                                  'nanosElapsed': 1264},
#                                                                                        'score': {'invocationCounts': {'score': 4},
#                                                                                                  'nanosElapsed': 11109}},
#                                                                              'type': 'BooleanQuery'}],
#                                                                    'mustNot': [],
#                                                                    'should': []},
#                                                           'stats': {'context': {'invocationCounts': {'createScorer': 12,
#                                                                                                      'createWeight': 1},
#                                                                                 'nanosElapsed': 2245414},
#                                                                     'match': {'invocationCounts': {'nextDoc': 10,
#                                                                                                    'refineRoughMatch': 4},
#                                                                               'nanosElapsed': 153533},
#                                                                     'score': {'invocationCounts': {'score': 4},
#                                                                               'nanosElapsed': 17134}},
#                                                           'type': 'BooleanQuery'},
#                                               'mongotQuery': {'compound': {'must': [{'text': {'path': 'title',
#                                                                                               'query': 'Fight '
#                                                                                                        'Club'}},
#                                                                                     {'range': {'gte': 1999,
#                                                                                                'lte': 1999,
#                                                                                                'path': 'year'}}]}}},
#              'executionTimeMillisEstimate': 6,
#              'nReturned': 0},
#             {'$_internalSearchIdLookup': {},
#              'executionTimeMillisEstimate': 6,
#              'nReturned': 0}]}

# %% [markdown]
# Then when you add `imdb` and `cast` to the query, you can still get performant results:

# %%
pipeline = [{
    "$search": {
      "compound": {
        "must": [
          {
            "text": {
              "query": "Fight",
              "path": "title"
            }
          },
          {
            "range": {
              "path": "year",
              "gte": 1999,
              "lte": 1999
            }
          },
            {
              "text": {
                "query": "Edward Norton",
                "path": "cast"
              }
            },
            {
              "range": {
                "gte": 9,
                "path": "imdb.rating"
              }
            }
          ]
        }
      }
    }
  ]
            
        
explain_plan = ExplainableCollection(
    collection, 
    verbosity="allPlansExecution"
).aggregate(pipeline)

pp.pprint(explain_plan)
# Out:
# {'$clusterTime': {'clusterTime': Timestamp(1664299192, 1),
#                   'signature': {'hash': b'\x9d\\\xdb\xaf\xaf\xc0\xba\x97j\xd5cJ'
#                                         b'\x11*\x94\x10\x00\x1c\xf3\xfa',
#                                 'keyId': 7109841346575204358}},
#  'command': {'$db': 'sample_mflix',
#              'aggregate': 'movies',
#              'cursor': {},
#              'pipeline': [{'$search': {'compound': {'must': [{'text': {'path': 'title',
#                                                                        'query': 'Fight'}},
#                                                              {'range': {'gte': 1999,
#                                                                         'lte': 1999,
#                                                                         'path': 'year'}},
#                                                              {'text': {'path': 'cast',
#                                                                        'query': 'Edward '
#                                                                                 'Norton'}},
#                                                              {'range': {'gte': 9,
#                                                                         'path': 'imdb.rating'}}]}}}]},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'operationTime': Timestamp(1664299192, 1),
#  'serverInfo': {'gitVersion': '32f0f9c88dc44a2c8073a5bd47cf779d4bfdee6b',
#                 'host': 'atlas-mrr4hc-shard-00-01.v7a3k.mongodb.net',
#                 'port': 27017,
#                 'version': '6.0.1'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0},
#  'stages': [{'$_internalSearchMongotRemote': {'explain': {'args': {'filter': [],
#                                                                    'minimumShouldMatch': 0,
#                                                                    'must': [{'args': {'filter': [],
#                                                                                       'minimumShouldMatch': 0,
#                                                                                       'must': [],
#                                                                                       'mustNot': [],
#                                                                                       'should': [{'args': {'path': 'cast',
#                                                                                                            'value': 'edward'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 126680},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'TermQuery'},
#                                                                                                  {'args': {'path': 'cast',
#                                                                                                            'value': 'norton'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 16,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 110037},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'TermQuery'}]},
#                                                                              'path': 'compound.must[2]',
#                                                                              'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                         'createWeight': 1},
#                                                                                                    'nanosElapsed': 506908},
#                                                                                        'match': {'nanosElapsed': 0},
#                                                                                        'score': {'nanosElapsed': 0}},
#                                                                              'type': 'BooleanQuery'},
#                                                                             {'args': {'filter': [],
#                                                                                       'minimumShouldMatch': 0,
#                                                                                       'must': [],
#                                                                                       'mustNot': [],
#                                                                                       'should': [{'args': {'gte': 1999.0,
#                                                                                                            'lte': 1999.0,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'double'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 4365},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 1999,
#                                                                                                            'lte': 1999,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'int64'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 3865},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 1999,
#                                                                                                            'lte': 1999,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'int64'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 14046},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 1999.0,
#                                                                                                            'lte': 1999.0,
#                                                                                                            'path': 'year',
#                                                                                                            'representation': 'double'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 500532},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'}]},
#                                                                              'path': 'compound.must[1]',
#                                                                              'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                         'createWeight': 1},
#                                                                                                    'nanosElapsed': 696566},
#                                                                                        'match': {'nanosElapsed': 0},
#                                                                                        'score': {'nanosElapsed': 0}},
#                                                                              'type': 'BooleanQuery'},
#                                                                             {'args': {'filter': [],
#                                                                                       'minimumShouldMatch': 0,
#                                                                                       'must': [],
#                                                                                       'mustNot': [],
#                                                                                       'should': [{'args': {'gte': 9,
#                                                                                                            'path': 'imdb.rating',
#                                                                                                            'representation': 'int64'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 7310},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 9.0,
#                                                                                                            'path': 'imdb.rating',
#                                                                                                            'representation': 'double'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 587663},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 9.0,
#                                                                                                            'path': 'imdb.rating',
#                                                                                                            'representation': 'double'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 6564},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'},
#                                                                                                  {'args': {'gte': 9,
#                                                                                                            'path': 'imdb.rating',
#                                                                                                            'representation': 'int64'},
#                                                                                                   'stats': {'context': {'invocationCounts': {'createScorer': 6,
#                                                                                                                                              'createWeight': 1},
#                                                                                                                         'nanosElapsed': 4463},
#                                                                                                             'match': {'nanosElapsed': 0},
#                                                                                                             'score': {'nanosElapsed': 0}},
#                                                                                                   'type': 'PointRangeQuery'}]},
#                                                                              'path': 'compound.must[3]',
#                                                                              'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                         'createWeight': 1},
#                                                                                                    'nanosElapsed': 713300},
#                                                                                        'match': {'nanosElapsed': 0},
#                                                                                        'score': {'nanosElapsed': 0}},
#                                                                              'type': 'BooleanQuery'},
#                                                                             {'args': {'path': 'title',
#                                                                                       'value': 'fight'},
#                                                                              'path': 'compound.must[0]',
#                                                                              'stats': {'context': {'invocationCounts': {'createScorer': 18,
#                                                                                                                         'createWeight': 1},
#                                                                                                    'nanosElapsed': 315502},
#                                                                                        'match': {'nanosElapsed': 0},
#                                                                                        'score': {'nanosElapsed': 0}},
#                                                                              'type': 'TermQuery'}],
#                                                                    'mustNot': [],
#                                                                    'should': []},
#                                                           'stats': {'context': {'invocationCounts': {'createScorer': 12,
#                                                                                                      'createWeight': 1},
#                                                                                 'nanosElapsed': 2726607},
#                                                                     'match': {'invocationCounts': {'nextDoc': 6},
#                                                                               'nanosElapsed': 138920},
#                                                                     'score': {'nanosElapsed': 0}},
#                                                           'type': 'BooleanQuery'},
#                                               'mongotQuery': {'compound': {'must': [{'text': {'path': 'title',
#                                                                                               'query': 'Fight'}},
#                                                                                     {'range': {'gte': 1999,
#                                                                                                'lte': 1999,
#                                                                                                'path': 'year'}},
#                                                                                     {'text': {'path': 'cast',
#                                                                                               'query': 'Edward '
#                                                                                                        'Norton'}},
#                                                                                     {'range': {'gte': 9,
#                                                                                                'path': 'imdb.rating'}}]}}},
#              'executionTimeMillisEstimate': 7,
#              'nReturned': 0},
#             {'$_internalSearchIdLookup': {},
#              'executionTimeMillisEstimate': 7,
#              'nReturned': 0}]}

# %% [markdown]
# [Link to blog post](#)
